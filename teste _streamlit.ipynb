# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# %%
st.set_page_config(page_title="Mini Power BI", layout="wide")

# ======================
# CARREGAR DADOS
# ======================
@st.cache_data
def carregar_dados():
    dim_clientes = pd.DataFrame({
        "id_cliente": [1, 2, 3],
        "cliente": ["Lucas", "Ana", "Pedro"],
        "estado": ["SP", "RJ", "MG"]
    })

    dim_produtos = pd.DataFrame({
        "id_produto": [10, 20, 30],
        "produto": ["Notebook", "Mouse", "Teclado"],
        "categoria": ["Informática", "Periféricos", "Periféricos"]
    })

    dim_datas = pd.DataFrame({
        "data": pd.to_datetime([
            "2024-01-01", "2024-01-02", "2024-01-03"
        ]),
        "ano": [2024, 2024, 2024],
        "mes": ["Jan", "Jan", "Jan"]
    })

    fato_vendas = pd.DataFrame({
        "id_cliente": [1, 2, 1, 3, 2],
        "id_produto": [10, 20, 30, 10, 30],
        "data": pd.to_datetime([
            "2024-01-01", "2024-01-01",
            "2024-01-02", "2024-01-03",
            "2024-01-03"
        ]),
        "valor": [3000, 150, 200, 3200, 180]
    })

    return dim_clientes, dim_produtos, dim_datas, fato_vendas


dim_clientes, dim_produtos, dim_datas, fato_vendas = carregar_dados()

# ======================
# SIDEBAR (SLICERS)
# ======================
st.sidebar.title("Filtros")

cliente_sel = st.sidebar.multiselect(
    "Cliente",
    options=dim_clientes["cliente"]
)

categoria_sel = st.sidebar.multiselect(
    "Categoria",
    options=dim_produtos["categoria"]
)

# ======================
# MODELAGEM (JOINS)
# ======================
df_modelo = (
    fato_vendas
    .merge(dim_clientes, on="id_cliente", how="left")
    .merge(dim_produtos, on="id_produto", how="left")
    .merge(dim_datas, on="data", how="left")
)

# ======================
# APLICAR FILTROS (IGUAL POWER BI)
# ======================
if cliente_sel:
    df_modelo = df_modelo[df_modelo["cliente"].isin(cliente_sel)]

if categoria_sel:
    df_modelo = df_modelo[df_modelo["categoria"].isin(categoria_sel)]

# ======================
# KPIs
# ======================
col1, col2, col3 = st.columns(3)

col1.metric("Total de Vendas", f"R$ {df_modelo['valor'].sum():,.2f}")
col2.metric("Qtde de Vendas", df_modelo.shape[0])
col3.metric("Clientes", df_modelo["cliente"].nunique())

# ======================
# GRÁFICOS
# ======================
st.markdown("### Vendas por Cliente")

fig_cliente = px.bar(
    df_modelo,
    x="cliente",
    y="valor",
    color="cliente",
    text_auto=True
)

st.plotly_chart(fig_cliente, use_container_width=True)

st.markdown("### Vendas por Categoria")

fig_categoria = px.pie(
    df_modelo,
    names="categoria",
    values="valor",
    hole=0.4
)

st.plotly_chart(fig_categoria, use_container_width=True)

# ======================
# TABELA DETALHADA
# ======================
st.markdown("### Detalhamento")
st.dataframe(df_modelo)
# Out:
# 2026-02-09 08:36:49.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.237 No runtime found, using MemoryCacheStorageManager
# 2026-02-09 08:36:49.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-09 08:36:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
